# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering, KMeans

# %%
image = plt.imread('lady-bug-bugs-ladybug.jpg')

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# (607, 910, 3)

# %%
X = image.reshape(-1, 3)

# %%
kmeans = KMeans(n_clusters=8, random_state=34).fit(X)

# %%
X_transformed = kmeans.fit_transform(X)

# %%
len(X_transformed)
# Out:
# 552370

# %%
plt.imshow(X_transformed)
