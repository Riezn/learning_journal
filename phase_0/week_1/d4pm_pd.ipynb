# %% [markdown]
# Data Loading

# %%
import numpy as np
import pandas as pd

# %%
#student_marks = pd.read_csv('Student_Marks.csv') kalau satu folder
df_student = pd.read_csv('../../../dataset/Student_Marks.csv')
#sep='' untuk separator atau delimiter=''
df_student
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
df_student.shape
# Out:
# (100, 3)

# %% [markdown]
# https://stackoverflow.com/questions/35466247/how-do-i-put-a-file-path-variable-into-pandas-read-csv

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %% [markdown]
# Data Overview

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...   40.29483     NYK    Knicks       68
# 1            0     NYK   Knicks  ...   41.70517     TRH   Huskies       66
#
#   opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0    1300.0  1306.7233              H            L  0.640065   NaN
# 1    1300.0  1293.2767              A            W  0.359935   NaN
#
# [2 rows x 23 columns]

# %%
pd.set_option('display.max.columns', None)

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %% [markdown]
# Data Exploration

# %%
df['game_result'].unique()
# Out:
# array(['L', 'W'], dtype=object)

# %%
df['game_result'].value_counts()
# Out:
# L    63157
# W    63157
# Name: game_result, dtype: int64

# %%
df['fran_id'].value_counts() #Lakers paling banyak bermain
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df.sort_values(by='pts',ascending=False)[['year_id','fran_id','pts']]
# Out:
#        year_id  fran_id  pts
# 50094     1984  Pistons  186
# 50095     1984  Nuggets  184
# 21416     1970   Pacers  177
# 32881     1975    Sails  176
# 8974      1959  Celtics  173
# ...        ...      ...  ...
# 4         1947  Falcons   33
# 3191      1951  Pistons   19
# 3190      1951   Lakers   18
# 26685     1973  Squires    2
# 26684     1973  Nuggets    0
#
# [126314 rows x 3 columns]

# %%
df.loc[df['fran_id']=='Knicks',['fran_id','year_id','opp_id','pts']]
# Out:
#        fran_id  year_id opp_id  pts
# 1       Knicks     1947    TRH   68
# 3       Knicks     1947    CHS   47
# 23      Knicks     1947    STB   68
# 37      Knicks     1947    CHS   68
# 54      Knicks     1947    PIT   64
# ...        ...      ...    ...  ...
# 126025  Knicks     2015    IND   86
# 126056  Knicks     2015    MIL   91
# 126072  Knicks     2015    ORL   80
# 126094  Knicks     2015    ATL  112
# 126147  Knicks     2015    DET   90
#
# [5769 rows x 4 columns]

# %%
df.loc[df['fran_id']=='Lakers',['team_id']].value_counts()
# Out:
# team_id
# LAL        5078
# MNL         946
# dtype: int64

# %%
df.loc[df['team_id']=='MNL',['year_id']].agg(['min','max'])
# Out:
#      year_id
# min     1949
# max     1960

# %% [markdown]
# Team Lakers MNL main dari 1949 s.d. 1960

# %%
df.loc[df['team_id']=='LAL',['year_id']].agg(['min','max'])
# Out:
#      year_id
# min     1961
# max     2015

# %% [markdown]
# Team Lakers MNL berganti nama menjadi Lakers LAL dan main dari 1961 s.d. 2016

# %%
a,b=df.loc[df['team_id']=='LAL',['seasongame','pts']].sum()

# %% [markdown]
# Lakers LAL bermain sebanyak 239037 game dan mencetak sebanyak 549215 poin

# %%
print(f'Lakers LAL bermain sebanyak {a} game dan mencetak sebanyak {b} poin')
# Out:
# Lakers LAL bermain sebanyak 239037 game dan mencetak sebanyak 549215 poin

# %% [markdown]
# ## Query

# %%
df[ #Isi query atau filter
    (df['year_id']==2001) &
    (df['fran_id']=='Celtics') &
    (df['game_location']=='H') &
    (df['game_result']=='W')   
]['opp_fran']
# Out:
# 87776      Pistons
# 87805      Raptors
# 87970      Wizards
# 88001        Hawks
# 88068      Rockets
# 88093        Magic
# 88233     Clippers
# 88336      Nuggets
# 88469         Nets
# 88748         Heat
# 88925        Hawks
# 88975         Suns
# 89013      Pistons
# 89105    Cavaliers
# 89141        Bucks
# 89364      Thunder
# 89425         Jazz
# 89525      Wizards
# 89756        Bulls
# 90057         Nets
# Name: opp_fran, dtype: object

# %%
df[ #Isi query atau filter
    (df['year_id']==2001) &
    (df['fran_id']=='Celtics') &
    (df['game_location']=='H') &
    (df['game_result']=='W')   
][['fran_id','pts','opp_fran','opp_pts']] #Ingat pakai [[]] karena kolom yang ditarik ada di dalam list
# Out:
#        fran_id  pts   opp_fran  opp_pts
# 87776  Celtics  103    Pistons       83
# 87805  Celtics   93    Raptors       91
# 87970  Celtics  116    Wizards      109
# 88001  Celtics  106      Hawks       99
# 88068  Celtics   96    Rockets       81
# 88093  Celtics  103      Magic       98
# 88233  Celtics   96   Clippers       87
# 88336  Celtics  104    Nuggets      102
# 88469  Celtics   99       Nets       86
# 88748  Celtics   88       Heat       76
# 88925  Celtics   83      Hawks       82
# 88975  Celtics   99       Suns       83
# 89013  Celtics   99    Pistons       87
# 89105  Celtics  103  Cavaliers       82
# 89141  Celtics   94      Bucks       91
# 89364  Celtics   85    Thunder       82
# 89425  Celtics  103       Jazz       99
# 89525  Celtics  104    Wizards       72
# 89756  Celtics  102      Bulls       98
# 90057  Celtics   95       Nets       88

# %% [markdown]
# Alternative

# %%
df.query(
    "year_id==2001 &\
    fran_id=='Celtics' &\
    game_location=='H' &\
    game_result=='W'"
)['opp_fran']
# Out:
# 87776      Pistons
# 87805      Raptors
# 87970      Wizards
# 88001        Hawks
# 88068      Rockets
# 88093        Magic
# 88233     Clippers
# 88336      Nuggets
# 88469         Nets
# 88748         Heat
# 88925        Hawks
# 88975         Suns
# 89013      Pistons
# 89105    Cavaliers
# 89141        Bucks
# 89364      Thunder
# 89425         Jazz
# 89525      Wizards
# 89756        Bulls
# 90057         Nets
# Name: opp_fran, dtype: object

# %% [markdown]
# ## Grouping

# %%
df.groupby('game_result')['pts'].sum()
# Out:
# game_result
# L    6148284
# W    6827951
# Name: pts, dtype: int64

# %%
df.groupby('game_result')['pts'].mean()
# Out:
# game_result
# L     97.349209
# W    108.110756
# Name: pts, dtype: float64

# %% [markdown]
# Query + Group By

# %%
df[
    (df['year_id']>=2010)&
    (df['fran_id']=='Spurs')
].groupby(['year_id','game_result'])['pts'].mean()
# Out:
# year_id  game_result
# 2010     L               93.947368
#          W              105.611111
# 2011     L               93.840000
#          W              106.698413
# 2012     L               94.350000
#          W              106.366667
# 2013     L               93.333333
#          W              106.232877
# 2014     L               96.925926
#          W              108.564103
# 2015     L               97.548387
#          W              106.224138
# Name: pts, dtype: float64

# %% [markdown]
# Aggregate

# %%
df[
    (df['year_id']>=2010)&
    (df['fran_id']=='Spurs')
].groupby(['year_id','game_result'])['pts'].agg(['min','max'])
# Out:
#                      min  max
# year_id game_result
# 2010    L             76  114
#         W             88  147
# 2011    L             71  115
#         W             89  125
# 2012    L             79  108
#         W             83  128
# 2013    L             83  109
#         W             84  134
# 2014    L             85  111
#         W             76  133
# 2015    L             81  125
#         W             89  130

# %%
df[
    (df['year_id']>=2010)&
    (df['fran_id']=='Spurs')
].groupby(['year_id','game_result']).agg({'pts':'mean','game_id':'count'})
# Out:
#                             pts  game_id
# year_id game_result
# 2010    L             93.947368       38
#         W            105.611111       54
# 2011    L             93.840000       25
#         W            106.698413       63
# 2012    L             94.350000       20
#         W            106.366667       60
# 2013    L             93.333333       30
#         W            106.232877       73
# 2014    L             96.925926       27
#         W            108.564103       78
# 2015    L             97.548387       31
#         W            106.224138       58

# %% [markdown]
# ## Manipulating Columns

# %%
df['selisih_poin'] = df['pts'] - df['opp_pts']

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df[:][['pts','opp_pts','selisih_poin']].head()
# Out:
#    pts  opp_pts  selisih_poin
# 0   66       68            -2
# 1   68       66             2
# 2   63       47            16
# 3   47       63           -16
# 4   33       50           -17

# %% [markdown]
# # Rename Column

# %%
df.rename(columns={'selisih_poin':'diff_pts'})
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df = df.rename(columns={'selisih_poin':'diff_pts'})

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.rename(columns={'diff_pts':'dif_pts'}, inplace=True) #gunanya sama dengan df =

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %% [markdown]
# # Drop Column

# %%
df.drop('dif_pts', axis=1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df['dummy'] = 0

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.drop(['dif_pts','dummy'],axis=1)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...
