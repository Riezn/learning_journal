# %%
import requests
import re

# %%
url = "https://gbf.wiki/SSR_Characters_List" #https://www.gramedia.com/categories/buku

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
path = r'C:\Users\Judan Syamsul Hadad\Downloads\chromedriver'

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
driver = webdriver.Chrome(path)
driver.get(url)
html = driver.page_source

soup = BeautifulSoup(html, "html.parser")
print(soup.prettify()[:700])
# Out:
# C:\Users\Judan Syamsul Hadad\AppData\Local\Temp\ipykernel_49796\707667432.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# <html class="client-js" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    SSR Characters List - Granblue Fantasy Wiki
#   </title>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"SSR_Characters_List","wgTitle":"SSR Characters List","wgCurRevisionId":438152,"wgRevisionId":438152,"wgArticleId":4086,"wgIsArticle":true,"wgIsRedirect"

# %%
tes = soup.find_all("a",title=True)
print(tes[0])
print(tes[0]['href'])
# Out:
# <a href="/All_Characters" title="All Characters">Character list</a>
# /All_Characters

# %%
i = 0
for tes in soup.find_all("a",title=re.compile("\w")):
    print(tes['title'])
    i+=1
# Out:
# All Characters
# Character Extended Mastery Perks
# Journal/Characters
# SR Characters List
# R Characters List
# NPC Characters List
# Abby
# Abby
# Category:Attack Characters
# Category:Human Characters
# Category:Axe Characters
# wikipedia:Emiri Katō
# Premium Draw
# Agielba
# Agielba
# Category:Defense Characters
# Category:Draph Characters
# Category:Sabre Characters
# wikipedia:Unshō Ishizuka
# wikipedia:Koji Ishii
# Draw
# Aglovale
# Aglovale
# Category:Attack Characters
# Category:Human Characters
# Category:Sabre Characters
# wikipedia:Tatsuhisa Suzuki
# Premium Draw
# Albert
# Albert
# Category:Attack Characters
# Category:Human Characters
# Category:Sabre Characters
# wikipedia:Hikaru Midorikawa
# Premium Draw
# Albert (Dark)
# Albert (Dark)
# Category:Attack Characters
# Category:Human Characters
# Category:Sabre Characters
# wikipedia:Hikaru Midorikawa
# Premium Draw
# Aletheia
# Aletheia
# Category:Attack Characters
# Category:Human Characters
# ...
